# %%
a = 3
b = 5 
a + b
# Out:
# 8

# %%
import pandas as pd

# %%
# Out:
#   regionid   qty
# 0      A01   100

# %%
# exception 로직추가

try:
    inDf = pd.read_csv("./dataset/sample.txt")
    inDf
except Exception as e:
    print(e)

# %%
inDf = pd.read_csv("./dataset/sample.txt")
inDf
# Out:
#   regionid   qty
# 0      A01   100
